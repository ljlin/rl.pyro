# %%
# !pip install pyro-ppl
# Out:
# Collecting pyro-ppl
#   Downloading pyro_ppl-1.7.0-py3-none-any.whl (678 kB)
#      |████████████████████████████████| 678 kB 7.9 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl) (1.19.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl) (3.3.0)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl) (1.10.0+cu111)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl) (4.62.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.9.0->pyro-ppl) (3.10.0.2)
# Installing collected packages: pyro-api, pyro-ppl
# Successfully installed pyro-api-0.1.2 pyro-ppl-1.7.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab/rl.pyro

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro
# !git config --global user.email "lijianlin1995@gmail.com"
# !git config --global user.name "Colab"
# !git clean -f
# !git fetch --all
# !git reset --hard origin/main
# !git pull
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# Fetching origin
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 1), reused 10 (delta 1), pack-reused 0
# Unpacking objects: 100% (10/10), done.
# From https://github.com/ljlin/rl.pyro
#  + 4d7cc63...ab68bac main       -> origin/main  (forced update)
# HEAD is now at ab68bac REINFORCE
# Already up to date.

# %%
import REINFORCE

# %%
import importlib
importlib.reload(REINFORCE)
# Out:
# <module 'REINFORCE' from '/content/drive/My Drive/Colab/rl.pyro/REINFORCE.py'>

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro/data
# CPU times: user 2.03 ms, sys: 21 µs, total: 2.05 ms
# Wall time: 1.97 ms

# %%
# %%time
REINFORCE.REINFORCE("hard").run()
# Out:
# Seed=1
# Training:
# R25(9.77702): 100%|██████████| 7500/7500 [06:46<00:00, 18.44it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.92281): 100%|██████████| 7500/7500 [07:12<00:00, 17.34it/s]
# Training finished!
# Seed=3
# Training:
# R25(86.7361): 100%|██████████| 7500/7500 [08:27<00:00, 14.77it/s]
# Training finished!
# Seed=4
# Training:
# R25(9.92063): 100%|██████████| 7500/7500 [03:23<00:00, 36.82it/s]
# Training finished!
# Seed=5
# Training:
# R25(73.3684): 100%|██████████| 7500/7500 [07:42<00:00, 16.22it/s]
# Training finished!
# CPU times: user 32min 56s, sys: 33.4 s, total: 33min 29s
# Wall time: 33min 33s

# %%
# %%time
REINFORCE.REINFORCE("soft", TEMPERATURE = 1).run()
# Out:
# Seed=1
# Training:
# R25(10.0307): 100%|██████████| 7500/7500 [05:36<00:00, 22.30it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.92282): 100%|██████████| 7500/7500 [02:15<00:00, 55.31it/s]
# Training finished!
# Seed=3
# Training:
# R25(129.941): 100%|██████████| 7500/7500 [08:43<00:00, 14.33it/s]
# Training finished!
# Seed=4
# Training:
# R25(131.505): 100%|██████████| 7500/7500 [10:25<00:00, 11.99it/s]
# Training finished!
# Seed=5
# Training:
# R25(111.958): 100%|██████████| 7500/7500 [08:31<00:00, 14.66it/s]
# Training finished!
# CPU times: user 35min, sys: 34.4 s, total: 35min 35s
# Wall time: 35min 33s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 1).run()
# Out:
# Seed=1
# Training:
# R25(200): 100%|██████████| 7500/7500 [24:41<00:00,  5.06it/s]
# Training finished!
# Seed=2
# Training:
# R25(183.96): 100%|██████████| 7500/7500 [25:43<00:00,  4.86it/s]
# Training finished!
# Seed=3
# Training:
# R25(193.28): 100%|██████████| 7500/7500 [31:18<00:00,  3.99it/s]
# Training finished!
# Seed=4
# Training:
# R25(66.84): 100%|██████████| 7500/7500 [26:40<00:00,  4.69it/s]
# Training finished!
# Seed=5
# Training:
# R25(162.12): 100%|██████████| 7500/7500 [30:24<00:00,  4.11it/s]
# Training finished!
# CPU times: user 2h 16min, sys: 2min 43s, total: 2h 18min 43s
# Wall time: 2h 18min 49s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.1).run()
# Out:
# Seed=1
# Training:
# R25(68.64):   6%|▌         | 451/7500 [00:50<13:12,  8.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-913f16415376> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.1).run()')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# /content/drive/My Drive/Colab/rl.pyro/REINFORCE.py in run(self, label)
#     186         # Train for different seeds
#     187         filename = utils.common.safe_filename(f"reinforce-{self.MODE}{label}-{self.ENV_NAME}-SEED={self.SEEDS}-TEMPERATURE={self.TEMPERATURE}")
# --> 188         curves = [self.train(seed) for seed in self.SEEDS]
#     189         with open(f'{filename}.csv', 'w') as csv:
#     190             numpy.savetxt(csv, numpy.asarray(curves), delimiter=',')
#
# /content/drive/My Drive/Colab/rl.pyro/REINFORCE.py in <listcomp>(.0)
#     186         # Train for different seeds
#     187         filename = utils.common.safe_filename(f"reinforce-{self.MODE}{label}-{self.ENV_NAME}-SEED={self.SEEDS}-TEMPERATURE={self.TEMPERATURE}")
# --> 188         curves = [self.train(seed) for seed in self.SEEDS]
#     189         with open(f'{filename}.csv', 'w') as csv:
#     190             numpy.savetxt(csv, numpy.asarray(curves), delimiter=',')
#
# /content/drive/My Drive/Colab/rl.pyro/REINFORCE.py in train(self, seed)
#     146         for epi in pbar:
#     147             if self.SVI_ON:
# --> 148                 OPT.step(env)
#     149                 trainRs += [self.traj[-1]]
#     150             else:
#
# /usr/local/lib/python3.7/dist-packages/pyro/infer/svi.py in step(self, *args, **kwargs)
#     143         # get loss and compute gradients
#     144         with poutine.trace(param_only=True) as param_capture:
# --> 145             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     146
#     147         params = set(
#
# /usr/local/lib/python3.7/dist-packages/pyro/infer/trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     138         loss = 0.0
#     139         # grab a trace from the generator
# --> 140         for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
#     141             loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(
#     142                 model_trace, guide_trace
#
# /usr/local/lib/python3.7/dist-packages/pyro/infer/elbo.py in _get_traces(self, model, guide, args, kwargs)
#     184         else:
#     185             for i in range(self.num_particles):
# --> 186                 yield self._get_trace(model, guide, args, kwargs)
#
# /usr/local/lib/python3.7/dist-packages/pyro/infer/trace_elbo.py in _get_trace(self, model, guide, args, kwargs)
#      56         """
#      57         model_trace, guide_trace = get_importance_trace(
# ---> 58             "flat", self.max_plate_nesting, model, guide, args, kwargs
#      59         )
#      60         if is_validation_enabled():
#
# /usr/local/lib/python3.7/dist-packages/pyro/infer/enum.py in get_importance_trace(graph_type, max_plate_nesting, model, guide, args, kwargs, detach)
#      62     model_trace = prune_subsample_sites(model_trace)
#      63
# ---> 64     model_trace.compute_log_prob()
#      65     guide_trace.compute_score_parts()
#      66     if is_validation_enabled():
#
# /usr/local/lib/python3.7/dist-packages/pyro/poutine/trace_struct.py in compute_log_prob(self, site_filter)
#     229                     try:
#     230                         log_p = site["fn"].log_prob(
# --> 231                             site["value"], *site["args"], **site["kwargs"]
#     232                         )
#     233                     except ValueError as e:
#
# /usr/local/lib/python3.7/dist-packages/pyro/distributions/torch.py in log_prob(self, value)
#     122                 assert logits.size(-1 - value.dim()) == 1
#     123             return logits.transpose(-1 - value.dim(), -1).squeeze(-1)
# --> 124         return super().log_prob(value)
#     125
#     126     def enumerate_support(self, expand=True):
#
# /usr/local/lib/python3.7/dist-packages/torch/distributions/categorical.py in log_prob(self, value)
#     115     def log_prob(self, value):
#     116         if self._validate_args:
# --> 117             self._validate_sample(value)
#     118         value = value.long().unsqueeze(-1)
#     119         value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# /usr/local/lib/python3.7/dist-packages/torch/distributions/distribution.py in _validate_sample(self, value)
#     284             return
#     285         assert support is not None
# --> 286         valid = support.check(value)
#     287         if not valid.all():
#     288             raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/torch/distributions/constraints.py in check(self, value)
#     248
#     249     def check(self, value):
# --> 250         return (value % 1 == 0) & (self.lower_bound <= value) & (value <= self.upper_bound)
#     251
#     252     def __repr__(self):
#
# KeyboardInterrupt:

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.01).run()

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.001).run()

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.0001).run()
