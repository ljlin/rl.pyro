# %%
# !pip install pyro-ppl
# Out:
# ...
#      |████████████████████████████████| 678 kB 15.6 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro
# !git config --global user.email "lijianlin1995@gmail.com"
# !git config --global user.name "Colab"
# !git clean -f
# !git clean -df
# !git stash
# !git fetch --all
# !git reset --hard origin/main
# !git pull origin main
# !git checkout -f main
# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# Fetching origin
# Checking out files: 100% (20/20), done.
# HEAD is now at 33b828d minor
# From https://github.com/ljlin/rl.pyro
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro

import AC

# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# /content/drive/MyDrive/Colab/rl.pyro/data

# %%
import importlib
importlib.reload(AC)
# Out:
# <module 'REINFORCE' from '/content/drive/My Drive/Colab/rl.pyro/REINFORCE.py'>

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro/data
# CPU times: user 2.03 ms, sys: 21 µs, total: 2.05 ms
# Wall time: 1.97 ms

# %%
# %%time
AC.AC("soft", TEMPERATURE = 100).run()
# Out:
# Seed=1
# Training:
# R25(179.28): 100%|██████████| 300/300 [01:22<00:00,  3.62it/s]
# Training finished!
# Seed=2
# Training:
# R25(184.04): 100%|██████████| 300/300 [01:20<00:00,  3.71it/s]
# Training finished!
# Seed=3
# Training:
# R25(164.64): 100%|██████████| 300/300 [01:19<00:00,  3.80it/s]
# Training finished!
# Seed=4
# Training:
# R25(182.04): 100%|██████████| 300/300 [01:20<00:00,  3.73it/s]
# Training finished!
# Seed=5
# Training:
# R25(170.84): 100%|██████████| 300/300 [01:24<00:00,  3.57it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 6min 43s, sys: 3.95 s, total: 6min 47s
# Wall time: 6min 47s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 100, SVI_EPOCHS=1).run()
# Out:
# Seed=1
# Training:
# R25(192.76): 100%|██████████| 300/300 [01:40<00:00,  2.99it/s]
# Training finished!
# Seed=2
# Training:
# R25(176.08): 100%|██████████| 300/300 [01:46<00:00,  2.83it/s]
# Training finished!
# Seed=3
# Training:
# R25(186.2): 100%|██████████| 300/300 [01:42<00:00,  2.94it/s]
# Training finished!
# Seed=4
# Training:
# R25(179.64): 100%|██████████| 300/300 [01:41<00:00,  2.97it/s]
# Training finished!
# Seed=5
# Training:
# R25(184.64): 100%|██████████| 300/300 [01:45<00:00,  2.85it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 8min 29s, sys: 4.23 s, total: 8min 34s
# Wall time: 8min 35s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 100, SVI_EPOCHS=10).run()
# Out:
# Seed=1
# Training:
# R25(172.28): 100%|██████████| 300/300 [06:04<00:00,  1.21s/it]
# Training finished!
# Seed=2
# Training:
# R25(173): 100%|██████████| 300/300 [06:06<00:00,  1.22s/it]
# Training finished!
# Seed=3
# Training:
# R25(166.08): 100%|██████████| 300/300 [06:06<00:00,  1.22s/it]
# Training finished!
# Seed=4
# Training:
# R25(183.64): 100%|██████████| 300/300 [06:11<00:00,  1.24s/it]
# Training finished!
# Seed=5
# Training:
# R25(139.8): 100%|██████████| 300/300 [06:08<00:00,  1.23s/it]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 30min 26s, sys: 16.7 s, total: 30min 42s
# Wall time: 30min 36s

# %%
# %%time
AC.AC("soft", TEMPERATURE = 10).run()
# Out:
# Seed=1
# Training:
# R25(155.48): 100%|██████████| 300/300 [01:32<00:00,  3.23it/s]
# Training finished!
# Seed=2
# Training:
# R25(132.4): 100%|██████████| 300/300 [01:28<00:00,  3.40it/s]
# Training finished!
# Seed=3
# Training:
# R25(165.64): 100%|██████████| 300/300 [01:33<00:00,  3.22it/s]
# Training finished!
# Seed=4
# Training:
# R25(193): 100%|██████████| 300/300 [01:33<00:00,  3.21it/s]
# Training finished!
# Seed=5
# Training:
# R25(183.04): 100%|██████████| 300/300 [01:26<00:00,  3.48it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 7min 25s, sys: 8.92 s, total: 7min 34s
# Wall time: 7min 34s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 10, SVI_EPOCHS=1).run()
# Out:
# Seed=1
# Training:
# R25(171.52): 100%|██████████| 300/300 [01:50<00:00,  2.71it/s]
# Training finished!
# Seed=2
# Training:
# R25(175.96): 100%|██████████| 300/300 [01:44<00:00,  2.86it/s]
# Training finished!
# Seed=3
# Training:
# R25(188.24): 100%|██████████| 300/300 [01:48<00:00,  2.76it/s]
# Training finished!
# Seed=4
# Training:
# R25(144.12): 100%|██████████| 300/300 [01:39<00:00,  3.02it/s]
# Training finished!
# Seed=5
# Training:
# R25(157.12): 100%|██████████| 300/300 [01:39<00:00,  3.00it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 8min 39s, sys: 4.14 s, total: 8min 43s
# Wall time: 8min 44s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 10, SVI_EPOCHS=10).run()
# Out:
# Seed=1
# Training:
# R25(172.2): 100%|██████████| 300/300 [06:19<00:00,  1.26s/it]
# Training finished!
# Seed=2
# Training:
# R25(149.92): 100%|██████████| 300/300 [06:13<00:00,  1.25s/it]
# Training finished!
# Seed=3
# Training:
# R25(174.08): 100%|██████████| 300/300 [06:11<00:00,  1.24s/it]
# Training finished!
# Seed=4
# Training:
# R25(182.56): 100%|██████████| 300/300 [06:11<00:00,  1.24s/it]
# Training finished!
# Seed=5
# Training:
# R25(163.2): 100%|██████████| 300/300 [06:08<00:00,  1.23s/it]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 30min 53s, sys: 17.1 s, total: 31min 10s
# Wall time: 31min 4s

# %%
# %%time
AC.AC("soft", TEMPERATURE = 1).run()
# Out:
# Seed=1
# Training:
# R25(158.24): 100%|██████████| 300/300 [01:30<00:00,  3.31it/s]
# Training finished!
# Seed=2
# Training:
# R25(130.64): 100%|██████████| 300/300 [01:23<00:00,  3.59it/s]
# Training finished!
# Seed=3
# Training:
# R25(170.56): 100%|██████████| 300/300 [01:26<00:00,  3.45it/s]
# Training finished!
# Seed=4
# Training:
# R25(192): 100%|██████████| 300/300 [01:30<00:00,  3.31it/s]
# Training finished!
# Seed=5
# Training:
# R25(183.44): 100%|██████████| 300/300 [01:29<00:00,  3.36it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 7min 17s, sys: 4.06 s, total: 7min 21s
# Wall time: 7min 21s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 1, SVI_EPOCHS=1).run()
# Out:
# Seed=1
# Training:
# R25(162.8): 100%|██████████| 300/300 [01:46<00:00,  2.82it/s]
# Training finished!
# Seed=2
# Training:
# R25(166.28): 100%|██████████| 300/300 [01:48<00:00,  2.78it/s]
# Training finished!
# Seed=3
# Training:
# R25(169.96): 100%|██████████| 300/300 [01:46<00:00,  2.82it/s]
# Training finished!
# Seed=4
# Training:
# R25(195.68): 100%|██████████| 300/300 [01:47<00:00,  2.79it/s]
# Training finished!
# Seed=5
# Training:
# R25(190.32): 100%|██████████| 300/300 [01:48<00:00,  2.77it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 8min 53s, sys: 4.13 s, total: 8min 57s
# Wall time: 8min 57s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 1, SVI_EPOCHS=10).run()
# Out:
# Seed=1
# Training:
# R25(188.2): 100%|██████████| 300/300 [06:15<00:00,  1.25s/it]
# Training finished!
# Seed=2
# Training:
# R25(174.08): 100%|██████████| 300/300 [06:19<00:00,  1.26s/it]
# Training finished!
# Seed=3
# Training:
# R25(186.36): 100%|██████████| 300/300 [06:17<00:00,  1.26s/it]
# Training finished!
# Seed=4
# Training:
# R25(193.88): 100%|██████████| 300/300 [06:21<00:00,  1.27s/it]
# Training finished!
# Seed=5
# Training:
# R25(198.24): 100%|██████████| 300/300 [06:17<00:00,  1.26s/it]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 31min 20s, sys: 17.2 s, total: 31min 37s
# Wall time: 31min 31s

# %%
# %%time
AC.AC("soft", TEMPERATURE = 0.1).run()
# Out:
# Seed=1
# Training:
# R25(188.8): 100%|██████████| 300/300 [01:31<00:00,  3.29it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.24): 100%|██████████| 300/300 [00:38<00:00,  7.76it/s]
# Training finished!
# Seed=3
# Training:
# R25(9.28): 100%|██████████| 300/300 [00:38<00:00,  7.73it/s]
# Training finished!
# Seed=4
# Training:
# R25(9.32): 100%|██████████| 300/300 [00:38<00:00,  7.78it/s]
# Training finished!
# Seed=5
# Training:
# R25(195.2): 100%|██████████| 300/300 [01:27<00:00,  3.43it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 4min 51s, sys: 3.93 s, total: 4min 55s
# Wall time: 4min 55s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 0.1, SVI_EPOCHS=1).run()
# Out:
# Seed=1
# Training:
# R25(200): 100%|██████████| 300/300 [01:52<00:00,  2.67it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.48): 100%|██████████| 300/300 [00:57<00:00,  5.22it/s]
# Training finished!
# Seed=3
# Training:
# R25(123.72): 100%|██████████| 300/300 [01:05<00:00,  4.59it/s]
# Training finished!
# Seed=4
# Training:
# R25(9.32): 100%|██████████| 300/300 [00:57<00:00,  5.20it/s]
# Training finished!
# Seed=5
# Training:
# R25(166.96): 100%|██████████| 300/300 [01:41<00:00,  2.95it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 6min 30s, sys: 4.01 s, total: 6min 34s
# Wall time: 6min 34s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 0.1, SVI_EPOCHS=10).run()
# Out:
# Seed=1
# Training:
# R25(9.4): 100%|██████████| 300/300 [05:24<00:00,  1.08s/it]
# Training finished!
# Seed=2
# Training:
# R25(139.72): 100%|██████████| 300/300 [06:16<00:00,  1.26s/it]
# Training finished!
# Seed=3
# Training:
# R25(9.28): 100%|██████████| 300/300 [05:25<00:00,  1.09s/it]
# Training finished!
# Seed=4
# Training:
# R25(187.28): 100%|██████████| 300/300 [06:14<00:00,  1.25s/it]
# Training finished!
# Seed=5
# Training:
# R25(132.48): 100%|██████████| 300/300 [06:10<00:00,  1.23s/it]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 29min 20s, sys: 17.5 s, total: 29min 37s
# Wall time: 29min 31s

# %%
# %%time
AC.AC("soft", TEMPERATURE = 0.01).run()
# Out:
# Seed=1
# Training:
# R25(174.92): 100%|██████████| 300/300 [01:34<00:00,  3.16it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.24): 100%|██████████| 300/300 [00:38<00:00,  7.79it/s]
# Training finished!
# Seed=3
# Training:
# R25(195.88): 100%|██████████| 300/300 [01:11<00:00,  4.18it/s]
# Training finished!
# Seed=4
# Training:
# R25(9.32): 100%|██████████| 300/300 [00:38<00:00,  7.71it/s]
# Training finished!
# Seed=5
# Training:
# R25(188.76): 100%|██████████| 300/300 [01:28<00:00,  3.39it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 5min 28s, sys: 4 s, total: 5min 32s
# Wall time: 5min 32s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 0.01, SVI_EPOCHS=1).run()
# Out:
# Seed=1
# Training:
# R25(199.48): 100%|██████████| 300/300 [01:48<00:00,  2.77it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.24): 100%|██████████| 300/300 [00:57<00:00,  5.18it/s]
# Training finished!
# Seed=3
# Training:
# R25(194.6): 100%|██████████| 300/300 [01:45<00:00,  2.84it/s]
# Training finished!
# Seed=4
# Training:
# R25(174.12): 100%|██████████| 300/300 [01:52<00:00,  2.67it/s]
# Training finished!
# Seed=5
# Training:
# R25(170.08): 100%|██████████| 300/300 [01:38<00:00,  3.03it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 7min 59s, sys: 4.26 s, total: 8min 3s
# Wall time: 8min 3s

# %%
# %%time
AC.AC("pyro", TEMPERATURE = 0.01, SVI_EPOCHS=10).run()
# Out:
# Seed=1
# Training:
# R25(188.08): 100%|██████████| 300/300 [06:15<00:00,  1.25s/it]
# Training finished!
# Seed=2
# Training:
# R25(9.24): 100%|██████████| 300/300 [05:24<00:00,  1.08s/it]
# Training finished!
# Seed=3
# Training:
# R25(174.44): 100%|██████████| 300/300 [06:16<00:00,  1.26s/it]
# Training finished!
# Seed=4
# Training:
# R25(9.32): 100%|██████████| 300/300 [05:26<00:00,  1.09s/it]
# Training finished!
# Seed=5
# Training:
# R25(200): 100%|██████████| 300/300 [06:14<00:00,  1.25s/it]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 29min 26s, sys: 17.2 s, total: 29min 44s
# Wall time: 29min 38s
