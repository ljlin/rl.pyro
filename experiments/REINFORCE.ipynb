# %% [markdown]
# <a href="https://colab.research.google.com/github/ljlin/rl.pyro/blob/main/experiments/REINFORCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyro-ppl
# Out:
# ...
#      |████████████████████████████████| 678 kB 10.0 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro
# !git config --global user.email "lijianlin1995@gmail.com"
# !git config --global user.name "Colab"
# !git clean -f
# !git clean -df
# !git stash
# !git fetch --all
# !git reset --hard origin/main
# !git pull origin main
# !git checkout -f main
# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# Fetching origin
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 47 (delta 20), reused 44 (delta 17), pack-reused 0
# Unpacking objects: 100% (47/47), done.
# From https://github.com/ljlin/rl.pyro
#    33b828d..549ca1e  main       -> origin/main
# Checking out files: 100% (60/60), done.
# HEAD is now at 549ca1e some experimental data
# From https://github.com/ljlin/rl.pyro
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# /content/drive/MyDrive/Colab/rl.pyro/data

# %%
# !git clean -df
# Out:
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.01.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.01.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.1.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.1.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=1.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=1.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=10.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=10.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=100.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=100.png
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.01.csv
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.01.png
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.1.csv
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.1.png
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=1.csv
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=1.png
# ...

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro

import REINFORCE

# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# /content/drive/MyDrive/Colab/rl.pyro/data

# %%
import importlib
importlib.reload(REINFORCE)
# Out:
# <module 'REINFORCE' from '/content/drive/My Drive/Colab/rl.pyro/REINFORCE.py'>

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro/data
# Out:
# /content/drive/MyDrive/Colab/rl.pyro/data

# %%
# %%time
REINFORCE.REINFORCE("hard").run()
# Out:
# Seed=1
# Training:
# R25(9.77702): 100%|██████████| 7500/7500 [06:46<00:00, 18.44it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.92281): 100%|██████████| 7500/7500 [07:12<00:00, 17.34it/s]
# Training finished!
# Seed=3
# Training:
# R25(86.7361): 100%|██████████| 7500/7500 [08:27<00:00, 14.77it/s]
# Training finished!
# Seed=4
# Training:
# R25(9.92063): 100%|██████████| 7500/7500 [03:23<00:00, 36.82it/s]
# Training finished!
# Seed=5
# Training:
# R25(73.3684): 100%|██████████| 7500/7500 [07:42<00:00, 16.22it/s]
# Training finished!
# CPU times: user 32min 56s, sys: 33.4 s, total: 33min 29s
# Wall time: 33min 33s

# %%
# %%time
REINFORCE.REINFORCE("soft", TEMPERATURE = 1).run()
# Out:
# Seed=1
# Training:
# R25(10.0307): 100%|██████████| 7500/7500 [05:36<00:00, 22.30it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.92282): 100%|██████████| 7500/7500 [02:15<00:00, 55.31it/s]
# Training finished!
# Seed=3
# Training:
# R25(129.941): 100%|██████████| 7500/7500 [08:43<00:00, 14.33it/s]
# Training finished!
# Seed=4
# Training:
# R25(131.505): 100%|██████████| 7500/7500 [10:25<00:00, 11.99it/s]
# Training finished!
# Seed=5
# Training:
# R25(111.958): 100%|██████████| 7500/7500 [08:31<00:00, 14.66it/s]
# Training finished!
# CPU times: user 35min, sys: 34.4 s, total: 35min 35s
# Wall time: 35min 33s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 1).run()
# Out:
# Seed=1
# Training:
# R25(200): 100%|██████████| 7500/7500 [24:41<00:00,  5.06it/s]
# Training finished!
# Seed=2
# Training:
# R25(183.96): 100%|██████████| 7500/7500 [25:43<00:00,  4.86it/s]
# Training finished!
# Seed=3
# Training:
# R25(193.28): 100%|██████████| 7500/7500 [31:18<00:00,  3.99it/s]
# Training finished!
# Seed=4
# Training:
# R25(66.84): 100%|██████████| 7500/7500 [26:40<00:00,  4.69it/s]
# Training finished!
# Seed=5
# Training:
# R25(162.12): 100%|██████████| 7500/7500 [30:24<00:00,  4.11it/s]
# Training finished!
# CPU times: user 2h 16min, sys: 2min 43s, total: 2h 18min 43s
# Wall time: 2h 18min 49s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.1).run()
# Out:
# Seed=1
# Training:
# R25(32): 100%|██████████| 7500/7500 [23:14<00:00,  5.38it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.4): 100%|██████████| 7500/7500 [07:56<00:00, 15.73it/s]
# Training finished!
# Seed=3
# Training:
# R25(100.8): 100%|██████████| 7500/7500 [18:08<00:00,  6.89it/s]
# Training finished!
# Seed=4
# Training:
# R25(199.92): 100%|██████████| 7500/7500 [29:50<00:00,  4.19it/s]
# Training finished!
# Seed=5
# Training:
# R25(197.96): 100%|██████████| 7500/7500 [35:11<00:00,  3.55it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 1h 51min 34s, sys: 2min 16s, total: 1h 53min 51s
# Wall time: 1h 54min 23s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.01).run()
# Out:
# Seed=1
# Training:
# R25(173.08): 100%|██████████| 7500/7500 [13:27<00:00,  9.28it/s]
# Training finished!
# Seed=2
# Training:
# R25(200): 100%|██████████| 7500/7500 [17:11<00:00,  7.27it/s]
# Training finished!
# Seed=3
# Training:
# R25(94.12): 100%|██████████| 7500/7500 [09:59<00:00, 12.52it/s]
# Training finished!
# Seed=4
# Training:
# R25(163.92): 100%|██████████| 7500/7500 [22:05<00:00,  5.66it/s]
# Training finished!
# Seed=5
# Training:
# R25(171.72): 100%|██████████| 7500/7500 [13:12<00:00,  9.46it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 1h 14min 16s, sys: 1min 26s, total: 1h 15min 42s
# Wall time: 1h 15min 57s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.001).run()
# Out:
# Seed=1
# Training:
# R25(167.12): 100%|██████████| 7500/7500 [23:12<00:00,  5.39it/s]
# Training finished!
# Seed=2
# Training:
# R25(81.76): 100%|██████████| 7500/7500 [12:24<00:00, 10.08it/s]
# Training finished!
# Seed=3
# Training:
# R25(142.12): 100%|██████████| 7500/7500 [11:13<00:00, 11.13it/s]
# Training finished!
# Seed=4
# Training:
# R25(199.68): 100%|██████████| 7500/7500 [19:53<00:00,  6.28it/s]
# Training finished!
# Seed=5
# Training:
# R25(61.04): 100%|██████████| 7500/7500 [06:09<00:00, 20.27it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 1h 11min 11s, sys: 1min 30s, total: 1h 12min 41s
# Wall time: 1h 12min 54s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.0001).run()
# Out:
# Seed=1
# Training:
# R25(85.84): 100%|██████████| 7500/7500 [14:54<00:00,  8.39it/s]
# Training finished!
# Seed=2
# Training:
# R25(46.44): 100%|██████████| 7500/7500 [06:43<00:00, 18.58it/s]
# Training finished!
# Seed=3
# Training:
# R25(39.36): 100%|██████████| 7500/7500 [09:28<00:00, 13.20it/s]
# Training finished!
# Seed=4
# Training:
# R25(200): 100%|██████████| 7500/7500 [18:09<00:00,  6.88it/s]
# Training finished!
# Seed=5
# Training:
# R25(42.8): 100%|██████████| 7500/7500 [07:39<00:00, 16.33it/s]
# No handles with labels found to put in legend.
# Training finished!
# CPU times: user 55min 35s, sys: 1min 18s, total: 56min 54s
# Wall time: 56min 55s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 10).run()
# Out:
# Seed=1
# Training:
# R25(96.36): 100%|██████████| 7500/7500 [11:44<00:00, 10.65it/s]
# Training finished!
# Seed=2
# Training:
# R25(109.64): 100%|██████████| 7500/7500 [10:10<00:00, 12.29it/s]
# Training finished!
# Seed=3
# Training:
# R25(70.92): 100%|██████████| 7500/7500 [09:54<00:00, 12.61it/s]
# Training finished!
# Seed=4
# Training:
# R25(63.32):  38%|███▊      | 2816/7500 [02:55<07:17, 10.70it/s]

# %%
from IPython import display
display.Image("./REINFORCE-pyro-CartPole-v0-SEED=12345-TEMPERATURE=10.png")

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 100).run()
# Out:
# Seed=1
# Training:
# R25(23.28): 100%|██████████| 7500/7500 [04:32<00:00, 27.52it/s]
# Training finished!
# Seed=2
# Training:
# R25(19.36): 100%|██████████| 7500/7500 [04:35<00:00, 27.21it/s]
# Training finished!
# Seed=3
# Training:
# R25(23.32): 100%|██████████| 7500/7500 [04:32<00:00, 27.52it/s]
# Training finished!
# Seed=4
# Training:
# R25(21.92):  30%|██▉       | 2220/7500 [01:17<03:12, 27.36it/s]

# %%
from IPython import display
display.Image("./REINFORCE-pyro-CartPole-v0-SEED=12345-TEMPERATURE=100.png")

# %%
print("test")
# Out:
# test
