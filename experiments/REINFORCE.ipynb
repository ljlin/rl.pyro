# %% [markdown]
# <a href="https://colab.research.google.com/github/ljlin/rl.pyro/blob/main/experiments/REINFORCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyro-ppl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro
# !git config --global user.email "lijianlin1995@gmail.com"
# !git config --global user.name "Colab"
# !git clean -f
# !git clean -df
# !git stash
# !git fetch --all
# !git reset --hard origin/main
# !git pull origin main
# !git checkout -f main
# %cd /content/drive/MyDrive/Colab/rl.pyro/experiments/
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# Fetching origin
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 47 (delta 20), reused 44 (delta 17), pack-reused 0
# Unpacking objects: 100% (47/47), done.
# From https://github.com/ljlin/rl.pyro
#    33b828d..549ca1e  main       -> origin/main
# Checking out files: 100% (60/60), done.
# HEAD is now at 549ca1e some experimental data
# From https://github.com/ljlin/rl.pyro
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# /content/drive/MyDrive/Colab/rl.pyro/data

# %%
# !git clean -df
# Out:
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.01.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.01.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.1.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.1.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=1.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=1.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=10.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=10.png
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=100.csv
# Removing AC-pyro-CartPole-v0-SEED=12345-TEMPERATURE=100.png
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.01.csv
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.01.png
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.1.csv
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=0.1.png
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=1.csv
# Removing AC-soft-CartPole-v0-SEED=12345-TEMPERATURE=1.png
# ...

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro

import REINFORCE

# %cd /content/drive/MyDrive/Colab/rl.pyro/experiments
# Out:
# /content/drive/MyDrive/Colab/rl.pyro
# /content/drive/MyDrive/Colab/rl.pyro/experiments

# %%
import importlib
importlib.reload(REINFORCE)
# Out:
# <module 'REINFORCE' from '/content/drive/My Drive/Colab/rl.pyro/REINFORCE.py'>

# %%
# %cd /content/drive/MyDrive/Colab/rl.pyro/experiments
# Out:
# /content/drive/MyDrive/Colab/rl.pyro/experiments

# %%
# %%time
REINFORCE.REINFORCE("hard", EPISODES=8000).run()
# Out:
# REINFORCE-hard-CartPole-v0-SEED=12345-TEMPERATURE=None
# Seed=1
# Training:
# R25(9.88518): 100%|██████████| 8000/8000 [07:58<00:00, 16.70it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.99444): 100%|██████████| 8000/8000 [08:24<00:00, 15.87it/s]
# Training finished!
# Seed=3
# Training:
# R25(86.3328): 100%|██████████| 8000/8000 [10:28<00:00, 12.72it/s]
# Training finished!
# Seed=4
# Training:
# R25(9.88628): 100%|██████████| 8000/8000 [03:59<00:00, 33.45it/s]
# Training finished!
# Seed=5
# Training:
# R25(81.5157): 100%|██████████| 8000/8000 [09:23<00:00, 14.20it/s]
# Training finished!
# No handles with labels found to put in legend.
# CPU times: user 39min 14s, sys: 41.2 s, total: 39min 56s
# Wall time: 40min 15s

# %%
# %%time
REINFORCE.REINFORCE("soft", TEMPERATURE = 1, EPISODES=8000).run()
# Out:
# REINFORCE-soft-CartPole-v0-SEED=12345-TEMPERATURE=1
# Seed=1
# Training:
# R25(9.88455): 100%|██████████| 8000/8000 [06:28<00:00, 20.58it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.99444): 100%|██████████| 8000/8000 [02:42<00:00, 49.18it/s]
# Training finished!
# Seed=3
# Training:
# R25(116.099): 100%|██████████| 8000/8000 [10:37<00:00, 12.55it/s]
# Training finished!
# Seed=4
# Training:
# R25(131.09): 100%|██████████| 8000/8000 [12:32<00:00, 10.63it/s]
# Training finished!
# Seed=5
# Training:
# R25(107.554): 100%|██████████| 8000/8000 [10:27<00:00, 12.75it/s]
# Training finished!
# No handles with labels found to put in legend.
# CPU times: user 41min 47s, sys: 42.9 s, total: 42min 30s
# Wall time: 42min 50s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 1, EPISODES=8000).run()
# Out:
# REINFORCE-pyro-CartPole-v0-SEED=12345-TEMPERATURE=1
# Seed=1
# Training:
# R25(113.6): 100%|██████████| 8000/8000 [43:08<00:00,  3.09it/s]
# Training finished!
# Seed=2
# Training:
# R25(58.08): 100%|██████████| 8000/8000 [23:30<00:00,  5.67it/s]
# Training finished!
# Seed=3
# Training:
# R25(47.36): 100%|██████████| 8000/8000 [27:05<00:00,  4.92it/s]
# Training finished!
# Seed=4
# Training:
# R25(143.2): 100%|██████████| 8000/8000 [56:56<00:00,  2.34it/s]
# Training finished!
# Seed=5
# Training:
# R25(46.48): 100%|██████████| 8000/8000 [16:46<00:00,  7.95it/s]
# Training finished!
# No handles with labels found to put in legend.
# CPU times: user 2h 42min 26s, sys: 4min 35s, total: 2h 47min 1s
# Wall time: 2h 47min 28s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.1, EPISODES=8000).run()
# Out:
# REINFORCE-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.1
# Seed=1
# Training:
# R25(101.44): 100%|██████████| 8000/8000 [23:48<00:00,  5.60it/s]
# Training finished!
# Seed=2
# Training:
# R25(9.24): 100%|██████████| 8000/8000 [10:46<00:00, 12.37it/s]
# Training finished!
# Seed=3
# Training:
# R25(150.52): 100%|██████████| 8000/8000 [48:36<00:00,  2.74it/s]
# Training finished!
# Seed=4
# Training:
# R25(197.64): 100%|██████████| 8000/8000 [1:01:46<00:00,  2.16it/s]
# Training finished!
# Seed=5
# Training:
# R25(197.28): 100%|██████████| 8000/8000 [43:25<00:00,  3.07it/s]
# Training finished!
# No handles with labels found to put in legend.
# CPU times: user 3h 2min 43s, sys: 5min 14s, total: 3h 7min 58s
# Wall time: 3h 8min 24s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.01, EPISODES=8000).run()
# Out:
# REINFORCE-pyro-CartPole-v0-SEED=12345-TEMPERATURE=0.01
# Seed=1
# Training:
# R25(68.16): 100%|██████████| 8000/8000 [32:24<00:00,  4.12it/s]
# Training finished!
# Seed=2
# Training:
# R25(114.64): 100%|██████████| 8000/8000 [28:17<00:00,  4.71it/s]
# Training finished!
# Seed=3
# Training:
# R25(104.2): 100%|██████████| 8000/8000 [51:33<00:00,  2.59it/s]
# Training finished!
# Seed=4
# Training:
# R25(109.84): 100%|██████████| 8000/8000 [26:53<00:00,  4.96it/s]
# Training finished!
# Seed=5
# Training:
# R25(145.56): 100%|██████████| 8000/8000 [27:43<00:00,  4.81it/s]
# Training finished!
# No handles with labels found to put in legend.
# CPU times: user 2h 41min 42s, sys: 4min 46s, total: 2h 46min 29s
# Wall time: 2h 46min 53s

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.001, EPISODES=8000).run()

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 0.0001, EPISODES=8000).run()

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 10, EPISODES=8000).run()

# %%
# %%time
REINFORCE.REINFORCE("pyro", TEMPERATURE = 100, EPISODES=8000).run()
